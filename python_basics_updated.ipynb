# %%
print("hello")
# Out:
# hello

# %%
pwd
# Out:
# '/Users/jatinbansal/Documents/SmartInternz_AIML'

# %% [markdown]
# # Heading

# %% [markdown]
# ### this is a subheading

# %% [raw]
# welcome, this is a comment

# %% [markdown]
# markdown

# %% [markdown]
# # Variables

# %%
a=10

# %%
a
# Out:
# 10

# %%
b="jatin"

# %%
c=23.7

# %%
c
# Out:
# 23.7

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
type(c)
# Out:
# float

# %%
a,b,c
# Out:
# (10, 'jatin', 23.7)

# %%
print("a",a,"b",b,"c",c)
# Out:
# a 10 b jatin c 23.7

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Indexing

# %%
string="hi how are you"

# %%
string[1]
# Out:
# 'i'

# %%
string[-2]
#-1 is last index
# Out:
# 'o'

# %%
#mutable->if u are able to change content

# %%
string[-2]="g"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 string[-2]="g"
#
# TypeError: 'str' object does not support item assignment

# %%
#bcoz strings are immutable

# %% [markdown]
# # Slicing

# %%
string
# Out:
# 'hi how are you'

# %%
string[3:]
# Out:
# 'how are you'

# %%
string[:6]
# Out:
# 'hi how'

# %%
string[3:12]
# Out:
# 'how are y'

# %%
string[-11:]
# Out:
# 'how are you'

# %%
dir(string)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %% [markdown]
# # list

# %%
#allow duplicates, heterogenous, changeable

# %%
p=[1,2,3.5,"jatin","smartbridge"]

# %%
type(p)
# Out:
# list

# %%
p
# Out:
# [1, 2, 3.5, 'jatin', 'smartbridge']

# %%
p[2]
# Out:
# 3.5

# %%
type(p[3])
# Out:
# str

# %%
len(p)
# Out:
# 5

# %%
p.append(9)

# %%
p
# Out:
# [1, 2, 3.5, 'jatin', 'smartbridge', 9]

# %%
p.insert(4,"internz")

# %%
p
# Out:
# [1, 2, 3.5, 'jatin', 'internz', 'smartbridge', 9]

# %%
p[-2]
# Out:
# 'smartbridge'

# %%
p.append("jatin")

# %%
p
# Out:
# [1, 2, 3.5, 'jatin', 'internz', 'smartbridge', 9, 'jatin']

# %%
p.remove("jatin")

# %%
p
# Out:
# [1, 2, 3.5, 'internz', 'smartbridge', 9, 'jatin']

# %%
p.pop(3)
# Out:
# 'internz'

# %%
p
# Out:
# [1, 2, 3.5, 'smartbridge', 9, 'jatin']

# %%
p.reverse()

# %%
p
# Out:
# ['jatin', 9, 'smartbridge', 3.5, 2, 1]

# %%
#list is mutable,ordered,allows duplicates,heterogenous

# %% [markdown]
# # tuple

# %%
#tuples are immutable

# %%
t=(5,8.8,"smartbridge")

# %%
type(t)
# Out:
# tuple

# %%
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
t[1]
# Out:
# 8.8

# %%
t[1:]
# Out:
# (8.8, 'smartbridge')

# %%
#no add or remove

# %%
a=list(t)
#f=tuple(a) for viceversa

# %%
a
# Out:
# [5, 8.8, 'smartbridge']

# %%
a.append(7)

# %%
a
# Out:
# [5, 8.8, 'smartbridge', 7]

# %%
b=(4,5,3)

# %%
c=a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 c=a+b
#
# TypeError: can only concatenate list (not "tuple") to list

# %%
 c=t+b

# %%
c
# Out:
# (5, 8.8, 'smartbridge', 4, 5, 3)

# %%
#allows duplicates

# %% [markdown]
# # Dictionary

# %%
cricket={"captain":"rohit","keeper":"KL","bowler":"siraj"}

# %%
cricket
# Out:
# {'captain': 'rohit', 'keeper': 'KL', 'bowler': 'siraj'}

# %%
type(cricket)
# Out:
# dict

# %%
cricket["bowler"]
# Out:
# 'siraj'

# %%
z={"alpha":['a1','b1','c1'],"number":[1,2,3]}

# %%
z
# Out:
# {'alpha': ['a1', 'b1', 'c1'], 'number': [1, 2, 3]}

# %%
dir(z)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
pair={4:5}

# %%
z.update(pair)

# %%
z
# Out:
# {'alpha': ['a1', 'b1', 'c1'], 'number': [1, 2, 3], 4: 5}

# %%
cricket.get("bowler")
# Out:
# 'siraj'

# %%
cricket.values()
# Out:
# dict_values(['rohit', 'KL', 'siraj'])

# %%
cricket.keys()
# Out:
# dict_keys(['captain', 'keeper', 'bowler'])

# %%
cricket.items()
# Out:
# dict_items([('captain', 'rohit'), ('keeper', 'KL'), ('bowler', 'siraj')])

# %%
dic={"emp_name":"Jatin","salary":1000,"experience":5,"designation":"ml intern"}

# %%
dic.pop("designation")
# Out:
# 'ml intern'

# %%
dic
# Out:
# {'emp_name': 'Jatin', 'salary': 1000, 'experience': 5}

# %%
dic.popitem()
#pops last entry item
# Out:
# ('experience', 5)

# %%
dic
# Out:
# {'emp_name': 'Jatin', 'salary': 1000}

# %% [markdown]
# # Sets

# %%
#no duplicates allowed
#heterogenous

# %%
s={1,2,3}

# %%
s
# Out:
# {1, 2, 3}

# %%
s.add('vit')

# %%
s
# Out:
# {1, 2, 3, 'vit'}

# %%
  s[1]
    #indexing and slicing not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 s[1]
#
# TypeError: 'set' object is not subscriptable

# %%
s2={1,2}

# %%
s2.add(2)

# %%
s2
#duplicates not acceptable
# Out:
# {1, 2}

# %%
s2.update([2,3,4])

# %%
s2
# Out:
# {1, 2, 3, 4}

# %%
s2.remove(2)

# %%
s2
# Out:
# {1, 3, 4}

# %%
s2.discard(3)

# %%
s2
# Out:
# {1, 4}

# %%
s3={1,2,3,4}
s4={2,4,5,6}
s5=s3.union(s4)
s5
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s5.clear()

# %%
s5
# Out:
# set()

# %%
dir(s5)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
